# %%
import sqlalchemy as sql

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn_empresas = sql.create_engine('postgresql://postgres:%24h%5B6%3B%3AsqyA4%25f6nL%5Bg@postgres.driva.io:5433/postgres')

# %%
df_empresas = pd.concat([df for df in pd.read_sql(
    sql.text(f'''
        SELECT
            cnpj,
            cnae_principal_grupo,
            cnae_principal_subclasse,
            uf,
            municipio,
            endereco,
            qtde_funcionarios,
            historico_funcionarios
        FROM clientes.verdera_empresas
    '''),
    chunksize=1e4,
    con=conn_empresas.connect()
)])

# %%
df_empresas.head()
# Out:
#              cnpj  cnae_principal_grupo  cnae_principal_subclasse  \
# 0  63254718000124                   161                   1610203
# 1  13346268000121                   310                   3101200
# 2  35100882000141                   161                   1610203
# 3  33131519000168                   452                   4520006
# 4  17684533000132                   682                   6822600
#
#                uf               municipio  \
# 0           BAHIA               TEOLANDIA
# 1  SANTA CATARINA             VIDAL RAMOS
# 2        MARANHAO               SAO BENTO
# 3           BAHIA  SANTO ANTONIO DE JESUS
# 4  RIO DE JANEIRO          RIO DE JANEIRO
#
#                                             endereco  qtde_funcionarios  \
# 0  RODOVIA BR 101 SITIO MANGUEIRA, 14 - ZONA BURI...                NaN
# 1            ESTRADA GERAL - ANTAS GORDAS - 88443000                NaN
# 2  RUA FELIPE CANDURU, 1173 - SAO CRISTOVAO - 652...                NaN
# 3   RODOVIA BA 028, 19 - BAIRRO SAO PAULO - 44571970                1.0
# 4  PRACA MAHATMA GANDHI, 14 - CENTRO - ANDAR 10, ...                NaN
#
#                               historico_funcionarios
# 0                                               None
# 1  [{'ano': 2015, 'qtde_funcionarios': 6}, {'ano'...
# 2                                               None
# 3                                               None
# 4                                               None

# %%
df_categorias = pd.read_csv('../../data/categorias.csv')
df_categorias.head()
# Out:
#    CNAE 5º Nível Categoria
# 0         210108    Carvão
# 1         220902    Carvão
# 2         500301    Carvão
# 3         500302    Carvão
# 4        2790201    Carvão

# %%
df_empresas = pd.merge(df_empresas, df_categorias, left_on='cnae_principal_subclasse', right_on='CNAE 5º Nível')
df_empresas.head()
# Out:
#              cnpj  cnae_principal_grupo  cnae_principal_subclasse         uf  \
# 0  63254718000124                   161                   1610203      BAHIA
# 1  35100882000141                   161                   1610203   MARANHAO
# 2  63257273000136                   161                   1610203      BAHIA
# 3  33131711000154                   161                   1610203     PARANA
# 4  48721732000105                   161                   1610203  SAO PAULO
#
#             municipio                                           endereco  \
# 0           TEOLANDIA  RODOVIA BR 101 SITIO MANGUEIRA, 14 - ZONA BURI...
# 1           SAO BENTO  RUA FELIPE CANDURU, 1173 - SAO CRISTOVAO - 652...
# 2            CATURAMA             RUA DA CLINICA, 02 - CENTRO - 46575000
# 3  RIO BRANCO DO IVAI  RUA RIO SAO FRANCISCO - PARQUE INDUSTRIAL - 86...
# 4             ITATIBA        BA TAPERA GRANDE - TAPERA GRANDE - 13257721
#
#    qtde_funcionarios historico_funcionarios  CNAE 5º Nível Categoria
# 0                NaN                   None        1610203   Madeira
# 1                NaN                   None        1610203   Madeira
# 2                NaN                   None        1610203   Madeira
# 3                NaN                   None        1610203   Madeira
# 4                NaN                   None        1610203   Madeira

# %%
df_empresas[~df_empresas['historico_funcionarios'].isna()]
# Out:
#                   cnpj  cnae_principal_grupo  cnae_principal_subclasse  \
# 8       33133406000100                   161                   1610203
# 14      78609930000800                   161                   1610203
# 20      78606563000115                   161                   1610203
# 21      78609930000134                   161                   1610203
# 32      78578812000378                   161                   1610203
# ...                ...                   ...                       ...
# 801633  83754986000201                   209                   2092403
# 801635  83754986000112                   209                   2092403
# 801636  83754986000546                   209                   2092403
# 801637  83757054000123                   209                   2092403
# 801638  33016338000190                   209                   2092403
#
#                         uf             municipio  \
# 8       MATO GROSSO DO SUL               CAARAPO
# 14          SANTA CATARINA         VARGEM BONITA
# 20          SANTA CATARINA            GUARAMIRIM
# 21          SANTA CATARINA               JOACABA
# 32             MATO GROSSO               COLNIZA
# ...                    ...                   ...
# 801633      SANTA CATARINA  SAO CRISTOVAO DO SUL
# 801635      SANTA CATARINA  SAO CRISTOVAO DO SUL
# 801636              PARANA            GUARAPUAVA
# 801637      SANTA CATARINA           CURITIBANOS
# 801638      RIO DE JANEIRO        RIO DE JANEIRO
#
#                                                  endereco  qtde_funcionarios  \
# 8                     RUA DR COUTINHO - CENTRO - 79940000                4.0
# 14                    PINHAL GRANDE - INTERIOR - 89675000               20.0
# 20      RUA PAULO BENTO DE AZEVEDO, 247 - ZONA RURAL -...               11.0
# 21         RUA FRANCISCO LINDNER, 290 - CENTRO - 89600000               19.0
# 32      ESTRADA DO OLEO KM2 - PROJETO DE ASSENTAMENTO ...                9.0
# ...                                                   ...                ...
# 801633  RUA LOURENCO FRANCA PEREIRA, 500 - CENTRO - 89...               80.0
# 801635  RODOVIA BR 116 - MEU POSTINHO - KM 179 - 89533000              559.0
# 801636           RODOVIA BR 277 KM 342,5 - CDI - 85100970              152.0
# 801637      RUA CEL VIDAL RAMOS, 1876 - CENTRO - 89520000              116.0
# 801638  AVENIDA DAS AMERICAS, 03500 - BARRA DA TIJUCA ...              134.0
#
#                                    historico_funcionarios  CNAE 5º Nível  \
# 8       [{'ano': 2015, 'qtde_funcionarios': 2}, {'ano'...        1610203
# 14      [{'ano': 2016, 'qtde_funcionarios': 14}, {'ano...        1610203
# 20      [{'ano': 2016, 'qtde_funcionarios': 8}, {'ano'...        1610203
# 21      [{'ano': 2016, 'qtde_funcionarios': 12}, {'ano...        1610203
# 32      [{'ano': 2017, 'qtde_funcionarios': 8}, {'ano'...        1610203
# ...                                                   ...            ...
# 801633  [{'ano': 2015, 'qtde_funcionarios': 51}, {'ano...        2092403
# 801635  [{'ano': 2015, 'qtde_funcionarios': 281}, {'an...        2092403
# 801636  [{'ano': 2015, 'qtde_funcionarios': 53}, {'ano...        2092403
# 801637  [{'ano': 2015, 'qtde_funcionarios': 72}, {'ano...        2092403
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...        2092403
#
#                   Categoria
# 8                   Madeira
# 14                  Madeira
# 20                  Madeira
# 21                  Madeira
# 32                  Madeira
# ...                     ...
# 801633  Material inflamável
# 801635  Material inflamável
# 801636  Material inflamável
# 801637  Material inflamável
# 801638  Material inflamável
#
# [98503 rows x 10 columns]

# %%
def padronizar_historico_funcionarios(linha):
    if isinstance(linha['historico_funcionarios'], list):
        if isinstance(linha['qtde_funcionarios'], float) and not np.isnan(linha['qtde_funcionarios']):
            hist = linha['historico_funcionarios'].copy()
            hist.append({
                'ano': 2023,
                'qtde_funcionarios': linha['qtde_funcionarios']
            })
            return hist
        
        return linha['historico_funcionarios']

    else:
        if isinstance(linha['qtde_funcionarios'], float):
            return [{
                'ano': 2023,
                'qtde_funcionarios': linha['qtde_funcionarios']
            }]

        return None

# %%
df_empresas['historico_funcionarios_padronizado'] = df_empresas.apply(padronizar_historico_funcionarios, axis=1)

# %%
df_empresas[~df_empresas['historico_funcionarios'].isna()][['historico_funcionarios', 'historico_funcionarios_padronizado']].head()
# Out:
#                                historico_funcionarios  \
# 8   [{'ano': 2015, 'qtde_funcionarios': 2}, {'ano'...
# 14  [{'ano': 2016, 'qtde_funcionarios': 14}, {'ano...
# 20  [{'ano': 2016, 'qtde_funcionarios': 8}, {'ano'...
# 21  [{'ano': 2016, 'qtde_funcionarios': 12}, {'ano...
# 32  [{'ano': 2017, 'qtde_funcionarios': 8}, {'ano'...
#
#                    historico_funcionarios_padronizado
# 8   [{'ano': 2015, 'qtde_funcionarios': 2}, {'ano'...
# 14  [{'ano': 2016, 'qtde_funcionarios': 14}, {'ano...
# 20  [{'ano': 2016, 'qtde_funcionarios': 8}, {'ano'...
# 21  [{'ano': 2016, 'qtde_funcionarios': 12}, {'ano...
# 32  [{'ano': 2017, 'qtde_funcionarios': 8}, {'ano'...

# %%
df_empresas_explode = df_empresas.explode('historico_funcionarios_padronizado')
df_empresas_explode[['historico_funcionarios', 'historico_funcionarios_padronizado']]
# Out:
#                                    historico_funcionarios  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
# 801639                                               None
#
#                historico_funcionarios_padronizado
# 0         {'ano': 2023, 'qtde_funcionarios': nan}
# 1         {'ano': 2023, 'qtde_funcionarios': nan}
# 2         {'ano': 2023, 'qtde_funcionarios': nan}
# 3         {'ano': 2023, 'qtde_funcionarios': nan}
# 4         {'ano': 2023, 'qtde_funcionarios': nan}
# ...                                           ...
# 801638    {'ano': 2018, 'qtde_funcionarios': 109}
# 801638     {'ano': 2019, 'qtde_funcionarios': 97}
# 801638    {'ano': 2020, 'qtde_funcionarios': 134}
# 801638  {'ano': 2023, 'qtde_funcionarios': 134.0}
# 801639    {'ano': 2023, 'qtde_funcionarios': nan}
#
# [1181672 rows x 2 columns]

# %%
df_empresas_explode[~df_empresas_explode['historico_funcionarios'].isna()][['historico_funcionarios', 'historico_funcionarios_padronizado']]
# Out:
#                                    historico_funcionarios  \
# 8       [{'ano': 2015, 'qtde_funcionarios': 2}, {'ano'...
# 8       [{'ano': 2015, 'qtde_funcionarios': 2}, {'ano'...
# 8       [{'ano': 2015, 'qtde_funcionarios': 2}, {'ano'...
# 8       [{'ano': 2015, 'qtde_funcionarios': 2}, {'ano'...
# 8       [{'ano': 2015, 'qtde_funcionarios': 2}, {'ano'...
# ...                                                   ...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
# 801638  [{'ano': 2015, 'qtde_funcionarios': 95}, {'ano...
#
#                historico_funcionarios_padronizado
# 8           {'ano': 2015, 'qtde_funcionarios': 2}
# 8           {'ano': 2016, 'qtde_funcionarios': 2}
# 8           {'ano': 2017, 'qtde_funcionarios': 2}
# 8           {'ano': 2018, 'qtde_funcionarios': 2}
# 8           {'ano': 2019, 'qtde_funcionarios': 2}
# ...                                           ...
# 801638     {'ano': 2017, 'qtde_funcionarios': 88}
# 801638    {'ano': 2018, 'qtde_funcionarios': 109}
# 801638     {'ano': 2019, 'qtde_funcionarios': 97}
# 801638    {'ano': 2020, 'qtde_funcionarios': 134}
# 801638  {'ano': 2023, 'qtde_funcionarios': 134.0}
#
# [478535 rows x 2 columns]

# %%
df_empresas_explode['historico_funcionarios_ano'] = df_empresas_explode['historico_funcionarios_padronizado'].apply(
    lambda h: h['ano'] if h is not None and h['ano'] else None
)

df_empresas_explode['historico_funcionarios_qtde'] = df_empresas_explode['historico_funcionarios_padronizado'].apply(
    lambda h: h['qtde_funcionarios'] if h is not None and h['qtde_funcionarios'] else None
)

# %%
df_empresas_explode[['cnpj', 'historico_funcionarios_padronizado', 'historico_funcionarios_ano', 'historico_funcionarios_qtde']].head()
# Out:
#              cnpj       historico_funcionarios_padronizado  \
# 0  63254718000124  {'ano': 2023, 'qtde_funcionarios': nan}
# 1  35100882000141  {'ano': 2023, 'qtde_funcionarios': nan}
# 2  63257273000136  {'ano': 2023, 'qtde_funcionarios': nan}
# 3  33131711000154  {'ano': 2023, 'qtde_funcionarios': nan}
# 4  48721732000105  {'ano': 2023, 'qtde_funcionarios': nan}
#
#    historico_funcionarios_ano  historico_funcionarios_qtde
# 0                        2023                          NaN
# 1                        2023                          NaN
# 2                        2023                          NaN
# 3                        2023                          NaN
# 4                        2023                          NaN

# %%
cols = [
    'cnpj',
    'cnae_principal_grupo',
    'cnae_principal_subclasse',
    'uf',
    'municipio',
    'endereco',
    'historico_funcionarios_ano',
    'historico_funcionarios_qtde'
]

df_empresas_explode[cols].head()
# Out:
#              cnpj  cnae_principal_grupo  cnae_principal_subclasse         uf  \
# 0  63254718000124                   161                   1610203      BAHIA
# 1  35100882000141                   161                   1610203   MARANHAO
# 2  63257273000136                   161                   1610203      BAHIA
# 3  33131711000154                   161                   1610203     PARANA
# 4  48721732000105                   161                   1610203  SAO PAULO
#
#             municipio                                           endereco  \
# 0           TEOLANDIA  RODOVIA BR 101 SITIO MANGUEIRA, 14 - ZONA BURI...
# 1           SAO BENTO  RUA FELIPE CANDURU, 1173 - SAO CRISTOVAO - 652...
# 2            CATURAMA             RUA DA CLINICA, 02 - CENTRO - 46575000
# 3  RIO BRANCO DO IVAI  RUA RIO SAO FRANCISCO - PARQUE INDUSTRIAL - 86...
# 4             ITATIBA        BA TAPERA GRANDE - TAPERA GRANDE - 13257721
#
#    historico_funcionarios_ano  historico_funcionarios_qtde
# 0                        2023                          NaN
# 1                        2023                          NaN
# 2                        2023                          NaN
# 3                        2023                          NaN
# 4                        2023                          NaN

# %%
df_empresas_explode.to_csv('../../data/final_empresas.csv', index=False)
