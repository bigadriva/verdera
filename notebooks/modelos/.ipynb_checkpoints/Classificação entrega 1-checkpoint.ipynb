# %%
import pandas as pd

# %%
df_empresas = pd.read_csv('../../data/final_empresas.csv')
df_empresas.head()
# Out:
#              cnpj  cnae_principal_grupo  cnae_principal_subclasse         uf  \
# 0  63254718000124                   161                   1610203      BAHIA
# 1  35100882000141                   161                   1610203   MARANHAO
# 2  63257273000136                   161                   1610203      BAHIA
# 3  33131711000154                   161                   1610203     PARANA
# 4  48721732000105                   161                   1610203  SAO PAULO
#
#             municipio                                           endereco  \
# 0           TEOLANDIA  RODOVIA BR 101 SITIO MANGUEIRA, 14 - ZONA BURI...
# 1           SAO BENTO  RUA FELIPE CANDURU, 1173 - SAO CRISTOVAO - 652...
# 2            CATURAMA             RUA DA CLINICA, 02 - CENTRO - 46575000
# 3  RIO BRANCO DO IVAI  RUA RIO SAO FRANCISCO - PARQUE INDUSTRIAL - 86...
# 4             ITATIBA        BA TAPERA GRANDE - TAPERA GRANDE - 13257721
#
#    qtde_funcionarios historico_funcionarios  CNAE 5º Nível Categoria  \
# 0                NaN                    NaN        1610203   Madeira
# 1                NaN                    NaN        1610203   Madeira
# 2                NaN                    NaN        1610203   Madeira
# 3                NaN                    NaN        1610203   Madeira
# 4                NaN                    NaN        1610203   Madeira
#
#         historico_funcionarios_padronizado  historico_funcionarios_ano  \
# 0  {'ano': 2023, 'qtde_funcionarios': nan}                        2023
# 1  {'ano': 2023, 'qtde_funcionarios': nan}                        2023
# 2  {'ano': 2023, 'qtde_funcionarios': nan}                        2023
# 3  {'ano': 2023, 'qtde_funcionarios': nan}                        2023
# 4  {'ano': 2023, 'qtde_funcionarios': nan}                        2023
#
#    historico_funcionarios_qtde
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %%
df_cadri = pd.read_csv('../../data/final_cadri.csv')
df_cadri.head()
# Out:
#            cnpj     ano tipo_unidade_padronizada unidade_padronizada  \
# 0  5.839444e+07  2013.0                    massa             ton/ano
# 1  1.221000e+09  2013.0                    massa             ton/ano
# 2  1.904000e+09  2017.0                    massa             ton/ano
# 3  1.904000e+09  2018.0                    massa             ton/ano
# 4  1.904000e+09  2020.0                    massa             ton/ano
#
#    qtde_padronizada  faixa_massa_residuo
# 0              0.06                    0
# 1            200.00                    0
# 2             65.00                    0
# 3            200.00                    0
# 4            200.00                    0

# %%
df_ibama = pd.read_csv('../../data/final_ibama.csv')
df_ibama.head()
# Out:
#          cnpj   ano tipo_unidade_padronizada  qtde_padronizada  \
# 0  1388000226  2016                   volume          15.10000
# 1  1388000226  2017                   volume           7.20000
# 2  1388000226  2018                   volume          14.40000
# 3  1388000226  2019                   volume           9.30000
# 4  1388000226  2016                    massa           2.57297
#
#   unidade_padronizada  faixa_massa_residuo
# 0              m3/ano                    0
# 1              m3/ano                    0
# 2              m3/ano                    0
# 3              m3/ano                    0
# 4             ton/ano                    0

# %%
df_fabricas = pd.read_csv('../../data/final_fabricas.csv')
df_fabricas.head()
# Out:
#   Unidade             Cidade Estado    CEP                lat  \
# 0     RBR  RIO BRANCO DO SUL     PR  83540  -25,3376341952381
# 1     VRA        VIDAL RAMOS     SC  88443        -27,3313244
# 2     SLT  SALTO DE PIRAPORA     SP  18160  -23,6679697772727
# 3     ITM      ITAU DE MINAS     MG  37975       -20,74468789
# 4     CAN          CANTAGALO     RJ  28500  -21,9552787928571
#
#                 long
# 0  -49,2647206238095
# 1  -49,4544744333333
# 2  -47,5948296681818
# 3        -46,7534126
# 4  -42,3413491214286

# %%
df_cbo = pd.read_csv('../../data/final_cbo.csv')
df_cbo.head()
# Out:
#          cnpj                                                cbo  \
# 0  1392000103  121010,141205,142205,212405,212420,252210,3011...
# 1  1392000103  121010,141205,142205,212405,212420,252210,3011...
# 2  1392000103  121010,141205,142205,212405,212420,252210,3011...
# 3  1392000103  121010,141205,142205,212405,212420,252210,3011...
# 4  1392000103  121010,141205,142205,212405,212420,252210,3011...
#
#                                            qtde_func   ano
# 0  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
# 1  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
# 2  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
# 3  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
# 4  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021

# %%
df_cbo = df_cbo.explode('cbo')

# %%
df_cbo.head()
# Out:
#          cnpj                                                cbo  \
# 0  1392000103  121010,141205,142205,212405,212420,252210,3011...
# 1  1392000103  121010,141205,142205,212405,212420,252210,3011...
# 2  1392000103  121010,141205,142205,212405,212420,252210,3011...
# 3  1392000103  121010,141205,142205,212405,212420,252210,3011...
# 4  1392000103  121010,141205,142205,212405,212420,252210,3011...
#
#                                            qtde_func   ano
# 0  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
# 1  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
# 2  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
# 3  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
# 4  1,1,1,1,2,2,1,3,2,7,1,2,1,7,7,1,4,2,4,2,1,12,4...  2021
